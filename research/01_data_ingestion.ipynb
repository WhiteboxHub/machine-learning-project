# %%
import os

# %%
# %pwd
# Out:
# 'c:\\Users\\dhira\\Desktop\\ALL_Projects\\Bunny_proj\\end-to-end-Machine-Learning-Project-with-MLflow'

# %%
os.chdir(r'c:\\Users\\dhira\\Desktop\\ALL_Projects\\Bunny_proj\\end-to-end-Machine-Learning-Project-with-MLflow')
